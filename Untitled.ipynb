# %%
test_accu = 5
test_loss = 6
df_res_test = pd.DataFrame({"Test accuracy":test_accu,"Test loss":test_loss},index=[0])
df_res_test.head()
# Out:
#    Test accuracy  Test loss
# 0              5          6

# %%
from classification_face import *
from utils import *
model_testing('CNN_2_2', annot_dir = 'img/cropped/RGB/', annot_path = 'test_set', other_face = False)
# Out:
# Test :
#  Accuracy: 92.1% 	 Avg loss: 0.386245
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92        83
#            1       0.91      0.93      0.92        81
#
#     accuracy                           0.92       164
#    macro avg       0.92      0.92      0.92       164
# weighted avg       0.92      0.92      0.92       164
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     350                 try:
# --> 351                     return self._range.index(new_key)
#     352                 except ValueError as err:
#
# ValueError: 164 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
from classification_face import *
annot_dir = "img/cropped/RGB/"
learning_rate = 1e-4
epochs = 1
weights_loss = [2., 2.]
main_loop(annot_dir = annot_dir, cnn = CNN_2, model_fn = 'test_nouveaux_csv', labels_type = 'Face', 
              weights_loss = weights_loss, learning_rate = learning_rate, epochs=epochs, 
              batch_size=32, other_class = False
          )
# Out:
# Nubmer of trainables parameters :308354
#
# Training model
#
# Epoch 1
# -------------------------------
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
